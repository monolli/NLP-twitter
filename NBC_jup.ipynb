# %%
#import sys
import re
import math

regex = r"[-'a-zA-ZÀ-ÖØ-öø-ÿ]+" 

class NBClassifier:

    def __init__(self, training_file=None):
        self.Data          = []
        self.Classes       = dict([])
        self.V             = set([])
        self.bigdoc        = dict([])

        self.logprior      = dict([])
        self.loglikelihood = dict([])

        if training_file is not None:
            self.load_data(training_file)

    def load_data(self, training_file):
        training_document = open(training_file,'r')

        for line in training_document.readlines():
            d, c = tuple(line.strip().split("\t"))
            self.Data.append((c,d))

            if c not in self.Classes:
                self.Classes[c] = 0
                self.bigdoc[c] = []
            self.Classes[c] += 1
            
            for w in re.findall(regex, d):
                self.V.add(w)
                self.bigdoc[c].append(w)
            
        print("Total: classes={} documentos={} vocabulario={}".format(len(self.Classes), len(self.Data), len(self.V) ) )

    def train(self):
        for c in self.Classes:
            Ndoc = len(self.Data)
            Nc   = self.Classes[c]

            self.logprior[c] = math.log(Nc/Ndoc)

            count_wc = 0
            for w in self.V:
                count_wc += self.bigdoc[c].count(w)

            for w in self.V:
                self.loglikelihood[(w,c)] = math.log( (self.bigdoc[c].count(w) + 1) / (count_wc + len(self.V) )  ) 

        print("\n", self.logprior)

    def test(self, testdoc):
        s = dict([])
        for c in self.Classes.keys():
            s[c] = self.logprior[c]
            for w in re.findall(regex, testdoc):
                if w in self.V:
                    s[c] += self.loglikelihood[(w,c)]
        return max(s, key=s.get)
 
    def test_batch(self, testing_file):
        testing_document = open(testing_file,'r')
        correct = 0
        total   = 0
        (tp, tn, fp, fn) = (0,0,0,0)

        for line in testing_document.readlines():
            total += 1
            d, c   = tuple(line.strip().split("\t"))
            result = NBC.test(d)
            print ("Classe_Verdadeira={} Classe_Identificada={}:\t{}".format(c, result, d))
            if c==result:
                correct += 1
            if c=='1' and result=='1':
                tp += 1
            if c=='0' and result=='1':
                fp += 1
            if c=='1' and result=='0':
                fn += 1
            if c=='0' and result=='0':
                tn += 1

        print ("\nCorrects = {}/{}\t\t\tAccuracy = {:.3f}".format(correct, total, correct/float(total) ))
        print ("Precision  = {:.3f}\t\t\tRecall = {:.3f}".format((tp)/(tp+fp),(tp)/(tp+fn)))
        print ("Negative Predictive Value = {:.3f}\tSpecificity = {:.3f}".format((tn)/(tn+fn),(tn)/(tn+fp)))
        print ('\n-Confusion matrix-')
        print (f' {tp}\t{fp}')
        print (f' {fn}\t{tn}')


if __name__ == '__main__':
    fileNameTrain = 'treino70.txt' #sys.argv[1]
    fileNameTest  = 'test30.txt' #sys.argv[2]

    NBC = NBClassifier(fileNameTrain)
    NBC.train()
    NBC.test_batch(fileNameTest)
# Out:
# Total: classes=2 documentos=317 vocabulario=1476
#
#  {'0': -0.6713054386448964, '1': -0.715476656958034}
# Classe_Verdadeira=0 Classe_Identificada=0:	divulg ser analis extrem relev concert injustiç pratic procur ent juiz dev ser pun poi utiliz pris ex-presid defend inter
# Classe_Verdadeira=1 Classe_Identificada=0:	ent ícon corrupç brasil articul ser presid sen banc cang corrupç plen campanh articul agor complet cardápi corrupt mai naçã qu afast deltan
# Classe_Verdadeira=1 Classe_Identificada=0:	é absurd é incr pt band insist alg tão absurd vam rua dia mostr cheg dess bagunç pt cheg esquerd
# Classe_Verdadeira=1 Classe_Identificada=0:	pens é deltan engan
# Classe_Verdadeira=0 Classe_Identificada=0:	ataqu milíc digit stf - após mostr dallagnol tent incrimin ministr cort superi - dirig apoi bolsonar vej começ tag ver trá
# Classe_Verdadeira=0 Classe_Identificada=1:	dest vez corret ser afast urgent desd fund quer cri dinh pov brasil est
# Classe_Verdadeira=1 Classe_Identificada=1:	apoi lógic apoi
# Classe_Verdadeira=1 Classe_Identificada=0:	desvi recurs públic conform númer recuper revel menos ano petist tiv mort falt medic recurs saúd estr dev cuid crei ter ultrapass mil
# Classe_Verdadeira=1 Classe_Identificada=1:	é contr vc é favor simpl assim infeliz parabém
# Classe_Verdadeira=1 Classe_Identificada=1:	ô do cad pra defend empresari pass mão cabeç eik dar palavr amig carg govern pf prend eik batist etap lava-jat rio
# Classe_Verdadeira=1 Classe_Identificada=1:	real nua cru é tod pilantr corrupt contr lavajat inclusiv corre transmiss míd
# Classe_Verdadeira=0 Classe_Identificada=0:	enquant preocup prejudic brasil fiz protest tratando- terror famíl boz atac cofr públic form quadrilh cad
# Classe_Verdadeira=1 Classe_Identificada=1:	entend quer quer continu combat quer convers fi é esquerd
# Classe_Verdadeira=0 Classe_Identificada=0:	bom dia resist anul ele fraud
# Classe_Verdadeira=0 Classe_Identificada=0:	vc leu últ diálog leman ambev financi vem pra rua q us procur lav jat p viabil jog xadr contr pt empr q banc vc part err é p est psl
# Classe_Verdadeira=0 Classe_Identificada=0:	é afront constitu sistem acusatóri q diz juiz q dev apen julg fez papel acus tal aí dodg defend suspend inquérit apur ofens ministr stf
# Classe_Verdadeira=0 Classe_Identificada=0:	dallagnol é crimin perig precis ser cont tud critic hoj revel pouc pert fiz deltan dallagnol possu cond permanec institu tão import democrac minist públic
# Classe_Verdadeira=1 Classe_Identificada=1:	tod apoi lav jat equip
# Classe_Verdadeira=1 Classe_Identificada=1:	fal sobr aqu desd começ explic repet histór é simpl tal itál falt apoi popul é brech quer continu corrupç un permanent mobil nenhum pov venc corrupç
# Classe_Verdadeira=0 Classe_Identificada=1:	dá defend ous reun mun contr maravil got d'águ peg arm defend mai ministr stf ninguém solt tog ninguém bolsominion arrepend
# Classe_Verdadeira=0 Classe_Identificada=0:	lul pres mor faz palestr remuner ensin inspir linch joaquim carvalh
# Classe_Verdadeira=0 Classe_Identificada=1:	inter é desvi atenç tir cord empr comunic ganh rio dinh govern bost vai faz mand qualqu cois pra bat pt
# Classe_Verdadeira=0 Classe_Identificada=0:	laranj aind sub hashtag teorilaranjadeltan dallagnolthamé danelonv pra rua
# Classe_Verdadeira=1 Classe_Identificada=1:	sit fofoc mostr é oper determin prend corrupt parabém trabalh
# Classe_Verdadeira=0 Classe_Identificada=0:	joic é oper grand empr estrang aniquil us pretext 'corrupção' ignor apo
# Classe_Verdadeira=1 Classe_Identificada=0:	afund lam podr arm orcrim contr pobr folh
# Classe_Verdadeira=0 Classe_Identificada=0:	famíl muit divers tod felic david glenn menin lind bolsonar mor dallagnol lava-jat crimin
# Classe_Verdadeira=0 Classe_Identificada=0:	moviment influenci escolh nov rela lav jat apen dia após mort ministr teor zavasck antig respons process oper supr
# Classe_Verdadeira=0 Classe_Identificada=0:	é organiz crimin benefici ascens fasc pod
# Classe_Verdadeira=1 Classe_Identificada=1:	cert pra vot deix oper morr
# Classe_Verdadeira=0 Classe_Identificada=0:	ataqu milíc digit stf - após mostr dallagnol tent incrimin ministr cort superi - dirig apoi bolsonar vej começ tag ver trá
# Classe_Verdadeira=1 Classe_Identificada=1:	invé stf hom pret ped afastamemt dev sr ministr stf faz antecipad afinal cont muit mordom pouc reproduz vem mostr eficác trabalh pun corrupt corrup
# Classe_Verdadeira=0 Classe_Identificada=0:	mor aind caiu
# Classe_Verdadeira=1 Classe_Identificada=1:	forç
# Classe_Verdadeira=1 Classe_Identificada=0:	rodrig é evid narr é desqualific sérgi mor
# Classe_Verdadeira=1 Classe_Identificada=0:	pens é deltan engan
# Classe_Verdadeira=0 Classe_Identificada=0:	herol morr overdos inimig pod
# Classe_Verdadeira=1 Classe_Identificada=1:	lav jat melhor remédi corrupç herol falt ministr fot obrig tod sempr
# Classe_Verdadeira=0 Classe_Identificada=0:	vou ped pra ser laranj outr cois melhor títul agor
# Classe_Verdadeira=1 Classe_Identificada=1:	é crak bem deix band nerv band acostum bem inert silenci levant brasil hom bem ágel compet diminu pequen alm gent melhor
# Classe_Verdadeira=1 Classe_Identificada=0:	liter agor lul é presidi
# Classe_Verdadeira=0 Classe_Identificada=0:	quant temp deltan dallagnol aind permanec frent aind membr minist públic procur crimin é vergonh institu tão import democrac brasil pod continu quadr
# Classe_Verdadeira=0 Classe_Identificada=0:	grand iron tátic mor deltan respost é lj lev dur ano vaz cl antié ileg oferec pres blog servil mencion aind ser divulg
# Classe_Verdadeira=0 Classe_Identificada=1:	podr podr podr sujeit é demon capaz faz qualqu cois pod imagin far consegu
# Classe_Verdadeira=0 Classe_Identificada=1:	gloss del premi extors medi sequestroprim dela zelot afirm ter sid 'obrigado' delat liber patrimôni
# Classe_Verdadeira=0 Classe_Identificada=0:	mor omit trf- menos palestr lid dor nov york
# Classe_Verdadeira=1 Classe_Identificada=1:	olh calm é difícil descobr real intenç canalh esquerd k esquerdalh unid acab desmoral conden juíz ministr procur feder cumpr lei repet ataqu solt fdp chef
# Classe_Verdadeira=0 Classe_Identificada=0:	laranj brasil cresc pra dúv expõ vem pra rua outr mov direit faz procur lav jat quer cumpr trabalh suj dar apoi artific ilegal crim procur juíz
# Classe_Verdadeira=1 Classe_Identificada=1:	bendit oper ano cidad bem esper
# Classe_Verdadeira=1 Classe_Identificada=1:	ant parec imposs hoj é real graç trabalh juiz sérgi mor oper lava-jat centen conden divers polít corrupt trabalh continu consig elimin corrupç brasil
# Classe_Verdadeira=1 Classe_Identificada=1:	lav jatotot incondic apoi procur espec tod ataqu sofr padr lázar
# Classe_Verdadeira=0 Classe_Identificada=0:	correg procurad viu condut conden sobr palestr procur ministr abr nenhum investig respeitosab cham conlui
# Classe_Verdadeira=1 Classe_Identificada=0:	esquec dess tr aqu dossi ser descart tud vem onyx lorenzon dav alcolumbr rodrig mai prest precis pgr defend
# Classe_Verdadeira=1 Classe_Identificada=1:	istoé mostr brasil crim continu send comand dentr cade marionet comun fal enquant soneg impost além defend presidi sonegado lav dinh palestr nunc fez institut
# Classe_Verdadeira=1 Classe_Identificada=1:	not envi sit procur diz reconhec mens public report recent dúv vam mostr chec nom seg
# Classe_Verdadeira=1 Classe_Identificada=1:	band entr desesper tod vez cheg pert
# Classe_Verdadeira=1 Classe_Identificada=1:	ra presid par gast temp energ capit polít dar carg filh ajud outr filh proteg justiç sob asa stf
# Classe_Verdadeira=1 Classe_Identificada=0:	min twitt ter ranç aind pesso ter corag continu agind heró anti-corrupç pq vergonh nenhum
# Classe_Verdadeira=1 Classe_Identificada=0:	veicul ment sobr ach cert burr
# Classe_Verdadeira=0 Classe_Identificada=0:	vc perceb procur repúbl peid fal séri
# Classe_Verdadeira=1 Classe_Identificada=1:	dev tem jeit muit aind tem continu
# Classe_Verdadeira=1 Classe_Identificada=1:	not envi sit procur diz reconhec mens public report recent dúv vam mostr chec nom seg
# Classe_Verdadeira=0 Classe_Identificada=1:	muit decepç pod imagin atu assim vai ver é assim sempr quer dirig rum país receb mai salári auxíli trambic diár control pod exager mão err
# Classe_Verdadeira=0 Classe_Identificada=1:	aind perplex bolsominiom atac cels mell qdo diz presid minimiz perigos import constitu temp aplaud barr diz mens deltan lav jat é fofoc
# Classe_Verdadeira=0 Classe_Identificada=0:	nov revel mostr procur deltan dallagnol agi man coorden mov supost independ direc rum oper lav jat acord inter particul
# Classe_Verdadeira=0 Classe_Identificada=0:	diz condut integr evidenc exist orcrim organiz crimin investig pesso
# Classe_Verdadeira=0 Classe_Identificada=0:	procur troc palavr ped peid convers vaz jat perdo red soc
# Classe_Verdadeira=1 Classe_Identificada=0:	ant fofoc ministr poi oq vem organiz bem arquitet planej únic obje ating tod oper apoi segment sociedad
# Classe_Verdadeira=1 Classe_Identificada=1:	oswald é tchutchuc perc temp vam public vault trech glenn buchtel atu aind assim irá defend verdevald
# Classe_Verdadeira=0 Classe_Identificada=0:	exclus chat priv revel colabor proib sergi mor deltan dallagnol
# Classe_Verdadeira=1 Classe_Identificada=0:	eik batist é pres nov fas lav jat agent cumpr mand busc apreens cas th olin batist filh empres
# Classe_Verdadeira=1 Classe_Identificada=0:	integr pcc diz diálog cabul pt linh diálog cabul ser investig fund sab revel corrupç petist país supost relaç pcc é opin
# Classe_Verdadeira=0 Classe_Identificada=0:	boz mor capach segu incólum enquant lul pres prov i n c r d i t á v l ps pcc taubaté cu é rol cad queiroz
# Classe_Verdadeira=1 Classe_Identificada=1:	soment é bem apo rest é ceg é burr rab pres
# Classe_Verdadeira=0 Classe_Identificada=0:	nov força-taref trat chef raquel dodg entrav busc driblá-l planej min imag mei vaz inform imprens
# Classe_Verdadeira=1 Classe_Identificada=1:	ofereç intens pr torc
# Classe_Verdadeira=0 Classe_Identificada=0:	mostr q dallagnol usou randolf vem pra rua mobil sociedad press stf confirma-s vez ess polít lav jat oper respons diret fornec clim eleg bolsonar lev sergi mor govern
# Classe_Verdadeira=1 Classe_Identificada=0:	lul livr larg ser ridícul
# Classe_Verdadeira=0 Classe_Identificada=0:	narcis acu dallagnol deu fal si pesso maluf trump pelé hulk voldemort et
# Classe_Verdadeira=0 Classe_Identificada=1:	kkkkk fars jat vc tosc ont saiu outr capítul aí hoj outr espetácul pirotécn kkkk convenc tosc
# Classe_Verdadeira=1 Classe_Identificada=1:	concord saíd magistrat err diss inúm vez por saiu tent implement agend contr retrocess avanç combat corrupç crim organiz aprov lei dur
# Classe_Verdadeira=1 Classe_Identificada=1:	pov vot vc merc vai sobr p fim esper pos qu esquerd pod d nov
# Classe_Verdadeira=0 Classe_Identificada=0:	turm respeit constitu ign lei orgân minist públic despr princípi básic étic aind pass cim hierarqu func pesso vergonh serv públic maior absolut honest
# Classe_Verdadeira=1 Classe_Identificada=0:	import import é trabalh maravilh vem faz lav jat total imparcial pod par
# Classe_Verdadeira=1 Classe_Identificada=1:	é patrimôni brasil vam pass brasil limp
# Classe_Verdadeira=0 Classe_Identificada=1:	alguém dúv real fac
# Classe_Verdadeira=0 Classe_Identificada=0:	oss dur ro vaz vaz geral vai vaz cheg vez thame danelon laranj detan expô
# Classe_Verdadeira=1 Classe_Identificada=0:	carl fern sant lim ra tod apoi lav jat equip
# Classe_Verdadeira=1 Classe_Identificada=0:	circul red soc imag supost diálog coorden força-taref curitib diálog mostr imag quest entant fals conf
# Classe_Verdadeira=0 Classe_Identificada=0:	mass manobr delt cristã cidad bem
# Classe_Verdadeira=1 Classe_Identificada=0:	engraç tão bom descobr cois quer é inter pov pref silenci lucr silênci fic quiet enquant govern anteri saque cofr públic
# Classe_Verdadeira=1 Classe_Identificada=1:	alguém dúv peg geral 'desespero' é nít emis part empr jornal ong' supr
# Classe_Verdadeira=0 Classe_Identificada=0:	lav jat é organiz crimin investig pesso diz ministr saib
# Classe_Verdadeira=0 Classe_Identificada=0:	laranj brasil cresc pra dúv expõ vem pra rua outr mov direit faz procur lav jat quer cumpr trabalh suj dar apoi artific ilegal crim procur juíz
# Classe_Verdadeira=1 Classe_Identificada=0:	gal parec youtub direit send ameaç mort døe rt
# Classe_Verdadeira=0 Classe_Identificada=0:	verdad nov via
# Classe_Verdadeira=1 Classe_Identificada=1:	pov apo é qu lul compars cade
# Classe_Verdadeira=1 Classe_Identificada=1:	apo
# Classe_Verdadeira=1 Classe_Identificada=1:	concord contig dit págin ofic bolsonar pod diz q risc assim asconden consegu através bolsonar pod indic deltan q const list dev abster-s criticá-l
# Classe_Verdadeira=1 Classe_Identificada=1:	exist mov intens orquestr retir coorden forç taref vam faz mov profund intercess vam mobil míd soc através hashtag
# Classe_Verdadeira=1 Classe_Identificada=1:	pessoal ter faz vá acompanh badern ex-presid lul hoj pres outr lug vão tard paran fez part deu exempl combat corrupç petist - graç ent juiz hoj ministr
# Classe_Verdadeira=1 Classe_Identificada=1:	segred oper psdb recorr gilm solt vez relaç tucan é antig desfrut fam detém inform privilegi
# Classe_Verdadeira=0 Classe_Identificada=0:	dallagnol recomend red artig jurist lavajat ped impeachment gilm
# Classe_Verdadeira=1 Classe_Identificada=1:	apoi pov brasil lut contr corrupç
# Classe_Verdadeira=0 Classe_Identificada=0:	us vem pra rua mud faz press contr stf nov sacrament lav jat é part polít usou est direit sórd manobr projet pod pra sort desmoron
# Classe_Verdadeira=0 Classe_Identificada=1:	rest dúv
# Classe_Verdadeira=0 Classe_Identificada=0:	moviment influenci escolh nov rela lav jat apen dia após mort ministr teor zavasck antig respons process oper supr
# Classe_Verdadeira=1 Classe_Identificada=1:	é coincid opos feroz lav jat feit esquerd corrupç deix ser mer proced crimin transform instrument tom manutenç pod lav jat desmont projet crimin pod
# Classe_Verdadeira=1 Classe_Identificada=1:	real nua cru é tod pilantr corrupt contr lavajat inclusiv corre transmiss míd
# Classe_Verdadeira=1 Classe_Identificada=1:	crim enquadr além recept vend conteúd roub alô
# Classe_Verdadeira=0 Classe_Identificada=0:	laranj brasil cresc pra dúv expõ vem pra rua outr mov direit faz procur lav jat quer cumpr trabalh suj dar apoi artific ilegal crim procur juíz
# Classe_Verdadeira=1 Classe_Identificada=1:	vc bem sab reform estrutur nad vai pra frent sab sempr asser opin é maqui quiç vc faç part grup ach acab econom vam deix roub bat palm foc
# Classe_Verdadeira=0 Classe_Identificada=0:	invenç marrec maring tent cal
# Classe_Verdadeira=0 Classe_Identificada=0:	afast deltan dallagnol é apen prim provid ser tom ato comet precis ser expuls minist públic defend crim comet dess institu tão import democrac est direit
# Classe_Verdadeira=0 Classe_Identificada=1:	gued corre comissionado gener golpistas orcrim gener golpistastrf moroddraquelminist bozomembr dept justiç eua apoi golp
# Classe_Verdadeira=0 Classe_Identificada=0:	mov é tremend mass manobr burr orelhud
# Classe_Verdadeira=0 Classe_Identificada=1:	requent pris tentatuv reacend fri bras decadenr oper pov pão curt circ arbítri
# Classe_Verdadeira=1 Classe_Identificada=1:	rest assim tod petist é tent desqualific pesso trabalh realiz membr papel imprens investig paralel far
# Classe_Verdadeira=1 Classe_Identificada=1:	kkkkk bem tod favor pap suj esquerd engan ninguém
# Classe_Verdadeira=0 Classe_Identificada=0:	gilm sinaliz abus lav jat favorec liberdad lul
# Classe_Verdadeira=1 Classe_Identificada=1:	devoluç ano ano petrobr r r r r r total r
# Classe_Verdadeira=1 Classe_Identificada=1:	exat reform neoliber funcion incompet car jb pib br arg cresc nunc ant gov esquerd vai neg imped apoi contr corrupç víde sai mal é sall galv usa ciênc contr mit
# Classe_Verdadeira=0 Classe_Identificada=0:	grand iron tátic mor deltan respost é lj lev dur ano vaz cl antié ileg oferec pres blog servil mencion aind ser divulg
# Classe_Verdadeira=1 Classe_Identificada=1:	apoi pov brasil lut contr corrupç
# Classe_Verdadeira=0 Classe_Identificada=0:	mor fez doaç declar ong mant empr envolv lav jat
# Classe_Verdadeira=0 Classe_Identificada=0:	susan rose-ackernan grand autoridad acadêm assunt é combat corrupç dúv é
# Classe_Verdadeira=1 Classe_Identificada=1:	vai acab pov irá deix
# Classe_Verdadeira=1 Classe_Identificada=1:	á verd justiç prevalec pod naçã int submiss magistr pass cim constituint
# Classe_Verdadeira=0 Classe_Identificada=0:	afast deltan dallagnol é apen prim provid ser tom ato comet precis ser expuls minist públic defend crim comet dess institu tão import democrac est direit
# Classe_Verdadeira=0 Classe_Identificada=0:	- gt nov vaz - gt parc el pal barrac nom sobrenom raquel dodg retrat procuradora-ger segund lav jat link via
# Classe_Verdadeira=0 Classe_Identificada=0:	segund br miniom hehe tag vem pra rua teor bomb hehe rat log começ sair bueir
# Classe_Verdadeira=1 Classe_Identificada=1:	exist mov intens orquestr retir coorden forç taref vam faz mov profund intercess vam mobil míd soc através hashtag
# Classe_Verdadeira=0 Classe_Identificada=0:	grand iron tátic mor deltan respost é lj lev dur ano vaz cl antié ileg oferec pres blog servil mencion aind ser divulg
# Classe_Verdadeira=1 Classe_Identificada=0:	delíc ver colun hoj ter admit set petróle fort tend cresc sustent falt diz é result
# Classe_Verdadeira=1 Classe_Identificada=1:	estranh monic benici nunc cit fabi cunh mariell franc lig milic oa tb nao cit fernand chav esp chef gabinet jaqu wagn lembr oa odebrecht entreg propin jw rio jan
#
# Corrects = 102/135			Accuracy = 0.756
# Precision  = 0.806			Recall = 0.704
# Negative Predictive Value = 0.712	Specificity = 0.812
#
# -Confusion matrix-
#  50	12
#  21	52
